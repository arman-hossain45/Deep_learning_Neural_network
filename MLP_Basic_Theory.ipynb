# %% [markdown]
# <a href="https://colab.research.google.com/github/arman-hossain45/Deep_learning_Neural_network/blob/main/MLP_Basic_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DL Assignment 02
#
# **Name:Mohammad Arman hossain**
#
# **Course Email:armanhossan890@gmail.com**
#
# This is a small assignment that connects topics from Module 1, 2, and 3.
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
# Explain gradient descent in detail. What is the main idea behind it? How does it help in minimizing the loss function? Explain the role of learning rate and describe what happens if the learning rate is too high or too low.

# %% [markdown]
# **Write** Answer 01:
#
# Gradient Descent  used in machine learning and deep learning to minimize the loss function by  updating the model parameters like weights and bias.
# The main objective of gradient descent is to find the optimal parameter values where the loss function reaches its minimum value.
#
# The idea of gradient descent is  based on the concept of moving in the opposite direction of the gradient means slope of the loss function.
#
# The gradient shows the direction of the steepest increase.
#
# To minimize the loss, we move in the opposite direction of the gradient.
#
# It is similar to going down a hill,
# If we want to reach the bottom, we move step by step in the downward slope direction.
#
#
# gradient descent helps  minimizing the parameter is by using this following steps like
#
# 1. initialize parameter
#
# 2.Calulate the loss
#
# 3.Compute  the gradient
#
# 4.upgrade the parameters
#
# 5.and Last repeat the process
#
# Here the role of learning rate
#
# learning rate determine the step size  taken during each upgrade.
# It controls how fast and slow the model learns
#
# When we take the learning rate is too high it may overshoot the minimun point and the loss may increase instead of decreasing and also the traing becomes unstable.
#
# When we take the learning rate is too Low: the training becomes too low ,it take long time  to take the minimum  ,also more iteration is required so that the cost is too   high

# %% [markdown]
# # Question 02: [ Marks 10 ]
#
# What is forward propagation in an artificial neural network? Explain step by step how data moves from the input layer to the output layer.

# %% [markdown]
# ## Write Answer 02:
# The forward propagation is the process in an ANN where input data passes through the network layer by layer to produce the final output
#
# ITs looks like
#
# Input layer -> Hidden layer->Outputlayer
#
# In forward propagation the network uses weights ,bias and activation functions to transform  the input into output
#
# here the expalanation the process step bu step :
#
# 1. Input layer receive data
#
# 2. Multiply input by Weights
#
# 3.Add bias
#
# 4.Apply the activatin function which is relu ,sigmoid and Tanh for example  this one function is use as a activation function.
#
# 5. pass output to hidden
#
# 6. Output layer produces final result
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Question 03: [ Marks 15 ]
# Why do we need activation functions in neural networks? What would happen if we only used linear transformations without any activation function?

# %% [markdown]
# ## Write Answer 03:
#
# An activation function  is a mathematical function applied to the output of a neuron .It introduces non-linearity into the neural network and teach the neuron to learn the complex patterns
#
# exampla: ReLU,Sigmoid,Tanh
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Why we use the Activation function  in ANN
#
# 1.To introduce NON-Linearity:
# real world data is mainly  non-linear ,activation function help the neuron learn these complex non-linear relationships,
# without the activation function , the network can only learn simple linear relationships
#
# 2.To enable multi layer learning : without activation functions ,adding more layers has no benefit .Activation functions make each layer learn different patterns.
#
# 3.To control output: convert output into probability like sigmoid and softmax , removes negative values like using the ReLU activation function
#
# If wee dont use the activation the function a neural network has multiple layers but no activation  function but the neuron is still a linear .No matter  how many layers we add , the network behaves like a single layer linear model its also cannot solve the compplex problems,cannot learn non-linear patterns

# %% [markdown]
# # Question 04: [ Marks 15 ]
#
# Explain the sigmoid activation function. Where is it used? What are its advantages and disadvantages? What problem does it cause during training?

# %% [markdown]
# ## Write Answer 04:

# %% [markdown]
# # Question 05: [ Marks 10 ]
# Explain the softmax activation function in simple words. Why is it used in multi-class classification problems? How is it different from sigmoid?

# %% [markdown]
# ## Write Answer 05:
#
# The sigmoid activation function is a mathematical function used in artificial neural networks to convert any real-valued number into a value between 0 and 1.
#
# ![image.png](data:image/png;base64,...)
#
# its mainly use in binary classification problem for example spam prediction yes or no ,Disease prediction yes or no ,its works looks like a logistic regression, because its output is 0 or 1 .
#
# *Advantage of sigmoid function is
#
# output between 0 and 1 like binanry classification
#
# Smooth and differentiable  helps in gradient descent training
#
# non-linear helps neural network learn complex patterns
#
# *Disadvantage of sigmoid function
#
# Vanishing gradient problem when input is very large or small gradient becomes almost zero
#
# output range is 0 and 1  but when comes range -1 to 1 its not useable
#
# Main disadvantage is vanishing gradient problem
#
#
# In modern network do not use sigmoid in hiddebn layer
#
# Because the main  problem is vanishing gradient problem is happen . Sigmoid is use in output layer for  binary classification .
#
# sigmoid causes the vanishing gradient problem, where gradients become very small and prevent proper learning in deep neural network thats why sigmoid is not use in hidden layers.

# %% [markdown]
# # Question 06: [ Marks 20 ]
#
# Explain the structure of an Artificial Neural Network in detail. Describe the role of the input layer, hidden layers, and output layer. How do weights, biases, and activation functions work together to transform input data into predictions? Illustrate your explanation with a simple example.

# %% [markdown]
# ## Write Answer 06:
#
# An Artificial Neural Network  is a computational model inspired by the human brain. It consists of neurons like nodes organized in layers. These layers work together to receive input data, process it, and produce an output (prediction).
#
# There are three main types of layers:
# 1 . Input layer
#
# 2 . Hidden layer
#
# 3 . Output layer
#
# here is one example
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Question 07: [ Marks 20 ]
#
#
# Train a neural network using TensorFlow Playground on any dataset other than XOR (for example, circles, spiral, or Gaussian). Use at least two hidden layers and select appropriate activation functions. Experiment with different numbers of neurons, learning rates, and regularization techniques.
#
# After training the model:
#
# Attach a screenshot of the model architecture and the final decision boundary.
#
# Report the training loss and any relevant observations.
#
# Analyze how the decision boundary evolved during training.
#
# Discuss whether the model shows signs of overfitting or underfitting.

# %% [markdown]
# Answer:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I used the Circles dataset from TensorFlow Playground. This dataset contains two classes:
#
# Inner circle (Blue class)
#
# Outer circle (Orange class)
#
# This is a non-linear classification problem, so hidden layers are required.
#
# here is From the screenshot, the neural network configuration is:
#
# Input features: X₁, X₂
#
# Hidden layers: 2
#
# Hidden Layer 1: 4 neurons
#
# Hidden Layer 2: 2 neurons
#
# Output layer: 1 neuron
#
# Activation function: Sigmoid
# Learning rate: 0.03
# Regularization: L2
# Regularization rate: 0.03
#
# From the OUTPUT panel:
#
# Training Loss = 0.002
#
# Test Loss = 0.006
#
# These values are very low, meaning the model learned successfully.
#
# Here is the final decision  boundary
#
# The decision boundary forms a closed circular shape
#
# Blue region correctly covers inner circle
#
# Orange region correctly covers outer circle
#
# This means the model learned the correct pattern.
#
#
# here ,
#
# neural network was trained using the circles dataset with two hidden layers containing 4 and 2 neurons. The sigmoid activation function and learning rate of 0.03 were used.
#
# After training, the training loss was 0.002 and test loss was 0.006, indicating good performance.
#
# The decision boundary evolved from a linear shape to a smooth circular boundary, correctly separating the two classes.
#
# Since both training and test loss are low and similar, the model shows good generalization and does not suffer from overfitting or underfitting.
