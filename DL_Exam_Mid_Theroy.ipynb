# %% [markdown]
# <a href="https://colab.research.google.com/github/arman-hossain45/Deep_learning_Neural_network/blob/main/DL_Exam_Mid_Theroy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DL Mid term exam
#
# **Name:MOHAMMAD ARMAN HOSSAIN**
#
# **Course Email:armanhossan890@gmail.com**
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# Draw a Neural Network
#
# Draw a neural network with:
#
# 3 input features
#
# 3 hidden layers (at least 2 neurons each)
#
# 1 output neuron
#
# a) Label all weights and biases. <br>
# b) Write the forward equations layer by layer. <br>
# c) If output uses Sigmoid, write the final prediction equation. <br>
#
# Please note : Don't forget to attach a screen short of your neural network.

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Question 02: [ Marks 20 ]
#
# Manual Gradient Calculation
#
# Given:
#
# z = w*x + b <br>
# y_pred = sigmoid(z) <br>
# L = −[ y log(y_pred) + (1−y) log(1−y_pred) ] <br>
#
# a) Write dL/dy_pred <br>
# b) Write dy_pred/dz <br>
# c) Show that dL/dz = y_pred − y <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Question 03: [ Marks 15 ]
#
# x = 3
# y1 = x^2
# y2 = 4*x
# L = y1 + y2
#
# a) Draw the computation graph. <br>
# b) Compute dL/dx manually. <br>
# c) Explain how would you do it using Autograd <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# code using auto grad
import torch

x= torch.tensor(3.0 , requires_grad = True)

y1 = x**2
y2 = 4*x

l=y1+y2

l.backward()

x.grad
# Out:
# tensor(10.)

# %% [markdown]
# # Question 04: [ Marks 15 ]
#
# Create a scalar tensor x = 3.0 with gradient tracking enabled. <br>
# Compute y = x² + 4x. <br>
# Perform backpropagation. <br>
# Print the gradient of x. <br>
#
# Write the full PyTorch code yourself. <br>

# %%
x = torch.tensor(3.0 , requires_grad = True)

y = x**2 + 4*x

y.backward()

x.grad
# Out:
# tensor(10.)

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# Create two tensors:
# w = 2.0 (requires_grad=True) <br>
# b = 1.0 (requires_grad=True) <br>
#
# Let input x = 3.0. <br>
# Compute z = w*x + b. <br>
# Use Sigmoid to get y_pred.
#  <br>
#
# Define Binary Cross Entropy manually (without built-in loss). <br>
# Compute gradients using backward(). <br>
# Print gradients of w and b. <br>
#
# Write full code.

# %%
# here the loss function of BCE

def bce_loss(y_pred,y):
  epsilon = 1e-8
  y=torch.clamp(y,epsilon,1-epsilon)

  return -(y*torch.log(y_pred)+(1-y)*torch.log(1-y_pred))


x = torch.tensor(3.0)
y = torch.tensor(0.0)

w = torch.tensor(2.0 , requires_grad=True)
b = torch.tensor(1.0 , requires_grad=True)

z = w*x + b

y_pred = torch.sigmoid(z)

print(y_pred)

loss = bce_loss(y_pred,y)
print(loss)

loss.backward()
w.grad
b.grad
# Out:
# tensor(0.9991, grad_fn=<SigmoidBackward0>)
# tensor(7.0010, grad_fn=<NegBackward0>)
# tensor(0.9991)

# %% [markdown]
# ## Write Answer 05:

# %% [markdown]
# # Question 06: [ Marks 10 ]
#
# Create a tensor x = 2.0 (requires_grad=True). <br>
# Compute:
#
# y1 = x² <br>
# y2 = 3x <br>
# L = y1 + y2 <br>
#
# Call backward(). <br>
# Print x.grad. <br>
#
# Write full PyTorch code.

# %%
# code using auto grad
import torch

x= torch.tensor(2.0 , requires_grad = True)

y1 = x**2
y2 = 3*x

l=y1+y2

l.backward()

x.grad
# Out:
# tensor(7.)

# %% [markdown]
# ## Write Answer 06:

# %% [markdown]
# # Question 07: [ Marks 20 ]
#
#
# Create tensor w = 2.0 (requires_grad=True). <br>
#
# Compute two different losses sequentially and call backward() twice. <br>
# Print w.grad. <br>
#
# Do not clear gradients. <br>
# Explain what you observe. <br>
#
# Write full code.

# %% [markdown]
# ## Write Answer 07:
#
# Here  there kis no loss function is given so we take two random loss function to calculate the auto gradients with out clear the gradients
#
# Here we take the first loss function is   : Loss1= x**2 . After gradients 2x
#
# And taker the secound loss funxction is   : Loss2=4x. Ater gradiients 4
#
# Here the code is below

# %%
w = torch.tensor(2.0 , requires_grad=True)

loss1  = w**2
loss2 = 4*w


loss1.backward()
print(w.grad)

loss2.backward()
print(w.grad)
# Out:
# tensor(4.)
# tensor(8.)

# %% [markdown]
# Here in bthis code it do not clear the gradients when we secound time calculate the gradients first 4 then 2nd 4 and its also add the 2nd 4 at the 2nd time 4+4=8 because we dont clear the gradients so 2nd time its show the 8 weight is exploding . So every time we should clear the gradient here the clear the ggradients code is given below

# %%
w = torch.tensor(2.0 , requires_grad=True)

loss1  = w**2
loss2 = 4*w


loss1.backward()
print(w.grad)

w.grad.zero_()

loss2.backward()
print(w.grad)
# Out:
# tensor(4.)
# tensor(4.)

# %% [markdown]
# Here in this code we see that it clear the gradients also because of the  w.grad.zeros_()
